# %%
import random

print("=== Escape the Vault ===")
print("You are trapped in a vault.")
print("Guess the correct code to escape!")

vault_code = random.randint(1,10)

player_guess = int(input("Enter the vault code (1-10): "))

if player_guess == vault_code:
    print("Vault opened! You escaped!")
else:
    print("Wrong code! The vault remains locked.")
# Out:
# === Escape the Vault ===
# You are trapped in a vault.
# Guess the correct code to escape!

# %%
import random

print("=== Escape the Vault ===")
print("You are trapped inside a vault.")
print("Guess the correct code to escape!")

vault_code = random.randint(1, 10)
attempts = 3

while attempts > 0:
    
    player_guess = int(input("Enter the vault code (1-10): "))

    if player_guess == vault_code:
        print("Vault opened! You escaped!")
        break

    elif player_guess < vault_code:
        print("Too low!")

    else:
        print("Too high!")

    attempts -= 1
    print("Attempts left:", attempts)

if attempts == 0:
    print("🚨 ALARM! Game over.")
    print("The correct code was:", vault_code)
