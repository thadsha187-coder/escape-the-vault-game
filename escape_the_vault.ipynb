# %%
import random


print("=== Escape the Vault🔒 ===")
print("You are trapped inside a vault.")
print("Guess the correct code to escape!")

#tracks the score throughout game
total_games = 0
total_wins = 0
total_losses = 0

def choose_difficulty():
    #ask the player to choose which level they want to play
    difficulty=input("Choose difficulty (easy or medium or hard):").lower()
   
    if difficulty =="easy":
        max_number =10
        attempts = 5
       
    elif difficulty =="medium":
        max_number = 30
        attempts= 4
   
    elif difficulty =="hard":
        max_number = 50
        attempts= 3
    else:
        print("Invalid choice.Defaulting to easy.")
        max_number =10
        attempts=5
    return max_number, attempts



while True:
    # Start a new round
    max_number, attempts = choose_difficulty()
    vault_code = random.randint(1, max_number)

    total_games += 1
    print(f"\nNew round started! (Range: 1-{max_number})")
    print(f"You have {attempts} attempts.\n")

    while attempts > 0:# loops continues until three attempts are over
        try:
            player_guess = int(input(f"Enter the vault code (1-{max_number} ): "))

            if player_guess < 1 or player_guess > max_number:
                print(f"Please enter a number between 1 and {max_number}.")
                continue  # goes back to the top of the loop without losing an attempt
           
            elif player_guess == vault_code: #checks if player guessed correcttly
                print("Vault opened! You escaped!")
                total_wins += 1
                break

            elif player_guess < vault_code:
                print("Too low!")

            else:
                print("Too high!")

            attempts -= 1 # this will reduce the number of attempts when the guess is wrong
            print("Attempts left:", attempts)
       
        except ValueError:
            print("Invalid input! ENTER A NUMBER!")# Runs if player enters something that isn' a number

    if attempts == 0:#if the player runs out of attempts then the game ends
        print("🚨 ALARM! Game over.")
        print("The correct code was:", vault_code)
        total_losses += 1
   
 #ask if they want to play again
    play_again = input('Play again?(y/n):').lower()
    if play_again != "y":
        print("\n=== GAME SCORE ===")
        print("Games Played:", total_games)
        print("Wins:", total_wins)
        print("Losses:", total_losses)
        print("Thanks for playing Escape the Vault 🔒")
        break
# Out:
# === Escape the Vault🔒 ===
# You are trapped inside a vault.
# Guess the correct code to escape!
# Choose difficulty (easy or medium or hard):hard
#
# New round started! (Range: 1-50)
# You have 3 attempts.
#
# Enter the vault code (1-50 ): 14
# Too low!
# Attempts left: 2
# Enter the vault code (1-50 ): 30
# Too high!
# Attempts left: 1
# Enter the vault code (1-50 ): 21
# Too low!
# Attempts left: 0
# 🚨 ALARM! Game over.
# The correct code was: 29
# Play again?(y/n):y
# Choose difficulty (easy or medium or hard):easy
#
# New round started! (Range: 1-10)
# You have 5 attempts.
#
# Enter the vault code (1-10 ): 3
# Too low!
# Attempts left: 4
# Enter the vault code (1-10 ): 4
# Too low!
# Attempts left: 3
# Enter the vault code (1-10 ): 9
# Too high!
# Attempts left: 2
# Enter the vault code (1-10 ): 7
# Too high!
# Attempts left: 1
# Enter the vault code (1-10 ): 6
# Vault opened! You escaped!
# Play again?(y/n):n
#
# === GAME SCORE ===
# Games Played: 2
# Wins: 1
# Losses: 1
# Thanks for playing Escape the Vault 🔒
